# %% [markdown]
# # DA Mini Project
# * 주제 : 온라인 학습 플랫폼 사용자 행동 패턴 분석
# * 개요 :
# ```
# 이번 프로젝트는 학습 서비스를 이용하는 독자들 중 누가 서비스 구독을 연장할지 예측하기 위한 사전 파악에 초점을 맞추고 있습니다. 우리의 목표는 유저들의 학습 습관, 선호도, 이용 행태 등 다양한 측면을 면밀히 분석하는 것입니다.
#
#
# 이를 위해, 우리는 유저들의 학습 패턴, 서비스 이용 시간, 콘텐츠에 대한 반응, 그리고 이들이 얼마나 자주 서비스를 이용하는지 등 다양한 데이터를 수집하고 분석할 계획입니다. 이 데이터는 유저들이 서비스에 얼마나 만족하고 있는지, 어떤 요소들이 그들의 구독 결정에 영향을 미치는지 이해하는 데 중요한 역할을 할 것입니다.
# ```
# * 데이터셋 : mini.csv
#     * 메타데이터
#         * user_id: 사용자의 고유 식별자
#         * subscription_duration: 사용자가 서비스에 가입한 기간 (월)
#         * recent_login_time: 사용자가 마지막으로 로그인한 시간 (일)
#         * average_login_time:  사용자의 일반적인 로그인 시간
#         * average_time_per_learning_session: 각 학습 세션에 소요된 평균 시간 (분)
#         * monthly_active_learning_days: 월간 활동적인 학습 일수
#         * total_completed_courses: 완료한 총 코스 수
#         * recent_learning_achievement: 최근 학습 성취도
#         * abandoned_learning_sessions: 중단된 학습 세션 수
#         * community_engagement_level: 커뮤니티 참여도
#         * preferred_difficulty_level: 선호하는 난이도
#         * subscription_type: 구독 유형
#         * customer_inquiry_history: 고객 문의 이력
#         * payment_pattern : 사용자의 지난 3개월 간의 결제 패턴을 10진수로 표현한 값.
#           - 7: 3개월 모두 결제함
#           - 6: 첫 2개월은 결제했으나 마지막 달에는 결제하지 않음
#           - 5: 첫 달과 마지막 달에 결제함
#           - 4: 첫 달에만 결제함
#           - 3: 마지막 2개월에 결제함
#           - 2: 가운데 달에만 결제함
#           - 1: 마지막 달에만 결제함
#           - 0: 3개월 동안 결제하지 않음
#         * target: 사용자가 다음 달에도 구독을 계속할지 (1) 또는 취소할지 (0)를 나타냄

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import koreanize_matplotlib 
import seaborn as sns

data = pd.read_table('data/mini.csv', sep=',')
data
# Out:
#        user_id  subscription_duration  recent_login_time  average_login_time  \
# 0     b919c29d                     13                 14           14.946163
# 1     a0a60abb                     16                 18           18.453224
# 2     b9f171ae                     22                  1           16.195228
# 3     5dc0ba8b                      1                 19           17.628656
# 4     65c83654                      4                  5           21.390656
# ...        ...                    ...                ...                 ...
# 9995  ae6b76bc                     22                 29           14.727623
# 9996  24588752                     10                 11           19.374054
# 9997  e4622a54                      7                 27           18.240978
# 9998  e07fbad9                     11                  7           18.783800
# 9999  e12dcb55                     10                  5           13.073230
#
#       average_time_per_learning_session  monthly_active_learning_days  \
# 0                              8.427187                            18
# 1                             72.646087                            16
# 2                             21.774492                            13
# 3                             42.659066                            19
# 4                             30.744287                            19
# ...                                 ...                           ...
# 9995                          84.053558                            18
# 9996                          45.464833                             9
# 9997                         127.302411                            24
# 9998                           5.297234                            10
# 9999                          28.120031                             3
#
#       total_completed_courses  recent_learning_achievement  \
# 0                          16                    68.360455
# 1                          13                    97.567322
# 2                          14                    94.358763
# 3                          18                    70.153228
# 4                          10                    81.917908
# ...                       ...                          ...
# 9995                       16                    64.966803
# 9996                        8                    82.750244
# 9997                       14                    81.567839
# 9998                       10                    89.885656
# 9999                       13                    64.811297
#
#       abandoned_learning_sessions  community_engagement_level  \
# 0                               3                           4
# 1                               2                           3
# 2                               3                           4
# 3                               0                           3
# 4                               2                           4
# ...                           ...                         ...
# 9995                            2                           5
# 9996                            3                           3
# 9997                            3                           5
# 9998                            4                           5
# 9999                            4                           5
#
#      preferred_difficulty_level subscription_type  customer_inquiry_history  \
# 0                           Low             Basic                         4
# 1                        Medium             Basic                         1
# 2                        Medium           Premium                         0
# 3                           Low             Basic                         1
# 4                        Medium             Basic                         3
# ...                         ...               ...                       ...
# 9995                        Low           Premium                         1
# 9996                     Medium             Basic                         2
# 9997                       High             Basic                         1
# 9998                        Low             Basic                         2
# 9999                        Low           Premium                         0
#
#       payment_pattern  target
# 0                   5       0
# 1                   6       1
# 2                   7       1
# 3                   0       1
# 4                   0       1
# ...               ...     ...
# 9995                1       1
# 9996                7       1
# 9997                6       1
# 9998                0       1
# 9999                3       0
#
# [10000 rows x 15 columns]

# %%
data_CV_target = data[['customer_inquiry_history', 'target']]
data_CV_target
# Out:
#       customer_inquiry_history  target
# 0                            4       0
# 1                            1       1
# 2                            0       1
# 3                            1       1
# 4                            3       1
# ...                        ...     ...
# 9995                         1       1
# 9996                         2       1
# 9997                         1       1
# 9998                         2       1
# 9999                         0       0
#
# [10000 rows x 2 columns]

# %%
counts = data_CV_target.groupby('customer_inquiry_history')['target'].value_counts().unstack(fill_value=0)
counts
# Out:
# target                       0     1
# customer_inquiry_history
# 0                          500   876
# 1                         1051  1617
# 2                          990  1655
# 3                          701  1150
# 4                          364   553
# 5                          140   245
# 6                           41    76
# 7                           10    21
# 8                            3     6
# 10                           1     0

# %%
colors = ['#a09cc9', '#6fb0d6']

counts.plot(kind='bar', rot=0, color=colors, width=0.6)
plt.title('고객 문의 이력과 구독 연장의 관계')
plt.xlabel('고객 문의 이력(건)')
plt.ylabel('구독 연장 고객수')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
data_sub_target = data[['subscription_duration', 'target']]
data_sub_target
# Out:
#       subscription_duration  target
# 0                        13       0
# 1                        16       1
# 2                        22       1
# 3                         1       1
# 4                         4       1
# ...                     ...     ...
# 9995                     22       1
# 9996                     10       1
# 9997                      7       1
# 9998                     11       1
# 9999                     10       0
#
# [10000 rows x 2 columns]

# %%
sub_counts = data_sub_target.groupby('subscription_duration')['target'].value_counts().unstack(fill_value=0)
sub_counts
# Out:
# target                   0    1
# subscription_duration
# 1                      172  264
# 2                      159  284
# 3                      128  280
# 4                      181  294
# 5                      169  255
# 6                      195  276
# 7                      158  274
# 8                      183  255
# 9                      172  268
# 10                     164  284
# 11                     166  262
# 12                     177  284
# 13                     153  284
# 14                     153  265
# 15                     158  250
# 16                     171  277
# 17                     152  277
# 18                     177  287
# 19                     156  267
# 20                     160  252
# 21                     166  267
# 22                     154  260
# 23                     177  233

# %%
colors = ['#a09cc9', '#6fb0d6']

sub_counts.plot(kind='bar', rot=0, color=colors, width=0.6)
plt.title('서비스에 가입한 기간과 구독 연장의 관계')
plt.xlabel('서비스에 가입한 기간(월)')
plt.ylabel('구독 연장 고객수')


plt.show()

# %%
df_freq = data[['average_time_per_learning_session', 'monthly_active_learning_days', 'community_engagement_level', 'total_completed_courses', 'recent_learning_achievement']]
df_freq
# Out:
#       average_time_per_learning_session  monthly_active_learning_days  \
# 0                              8.427187                            18
# 1                             72.646087                            16
# 2                             21.774492                            13
# 3                             42.659066                            19
# 4                             30.744287                            19
# ...                                 ...                           ...
# 9995                          84.053558                            18
# 9996                          45.464833                             9
# 9997                         127.302411                            24
# 9998                           5.297234                            10
# 9999                          28.120031                             3
#
#       community_engagement_level  total_completed_courses  \
# 0                              4                       16
# 1                              3                       13
# 2                              4                       14
# 3                              3                       18
# 4                              4                       10
# ...                          ...                      ...
# 9995                           5                       16
# 9996                           3                        8
# 9997                           5                       14
# 9998                           5                       10
# 9999                           5                       13
#
#       recent_learning_achievement
# 0                       68.360455
# 1                       97.567322
# 2                       94.358763
# 3                       70.153228
# 4                       81.917908
# ...                           ...
# 9995                    64.966803
# 9996                    82.750244
# 9997                    81.567839
# 9998                    89.885656
# 9999                    64.811297
#
# [10000 rows x 5 columns]

# %%
corr = df_freq.corr()
new_index = {'average_time_per_learning_session': '각 학습 세션에 소요된 평균 시간', 'monthly_active_learning_days': '활동적인 학습 일수(월)', 'community_engagement_level': '커뮤니티 활동지수', 'total_completed_courses': '완료한 총 코스 수', 'recent_learning_achievement': '최근 학습 성취도'}
new_columns = {'average_time_per_learning_session': '각 학습 세션에 소요된 평균 시간', 'monthly_active_learning_days': '활동적인 학습 일수(월)', 'community_engagement_level': '커뮤니티 활동지수', 'total_completed_courses': '완료한 총 코스 수', 'recent_learning_achievement': '최근 학습 성취도'}
corr = corr.rename(columns=new_columns, index=new_index)
corr
# Out:
#                     각 학습 세션에 소요된 평균 시간  활동적인 학습 일수(월)  커뮤니티 활동지수  완료한 총 코스 수  \
# 각 학습 세션에 소요된 평균 시간            1.000000      -0.001678   0.086485    0.081332
# 활동적인 학습 일수(월)                -0.001678       1.000000   0.000700    0.004816
# 커뮤니티 활동지수                     0.086485       0.000700   1.000000    0.266026
# 완료한 총 코스 수                    0.081332       0.004816   0.266026    1.000000
# 최근 학습 성취도                    -0.008231       0.030110  -0.000810   -0.002416
#
#                     최근 학습 성취도
# 각 학습 세션에 소요된 평균 시간  -0.008231
# 활동적인 학습 일수(월)        0.030110
# 커뮤니티 활동지수           -0.000810
# 완료한 총 코스 수          -0.002416
# 최근 학습 성취도            1.000000

# %%
sns.heatmap(corr, annot=True, fmt=".1%", cmap='PuBu')
plt.xticks(rotation= -10)
plt.yticks(rotation= 0)
plt.show()

# %%
data_avg = data[['average_time_per_learning_session', 'target']]
data_avg
# Out:
#       average_time_per_learning_session  target
# 0                              8.427187       0
# 1                             72.646087       1
# 2                             21.774492       1
# 3                             42.659066       1
# 4                             30.744287       1
# ...                                 ...     ...
# 9995                          84.053558       1
# 9996                          45.464833       1
# 9997                         127.302411       1
# 9998                           5.297234       1
# 9999                          28.120031       0
#
# [10000 rows x 2 columns]

# %%
data_avg.describe()
# Out:
#        average_time_per_learning_session        target
# count                       10000.000000  10000.000000
# mean                           54.917720      0.619900
# std                            56.024310      0.485435
# min                             0.011515      0.000000
# 25%                            15.276611      0.000000
# 50%                            37.578818      1.000000
# 75%                            75.584200      1.000000
# max                           503.372616      1.000000

# %%
target_1 = data_avg[data_avg['target'] == 1]['average_time_per_learning_session']
target_0 = data_avg[data_avg['target'] == 0]['average_time_per_learning_session']

plt.figure(figsize=(10, 6))
plt.hist(target_1, bins=30, alpha=0.5, color='#a09cc9', label='구독 연장 O')
plt.hist(target_0, bins=30, alpha=0.5, color='#6fb0d6', label='구독 연장 X')
plt.xlabel('각 학습에 소요된 평균 시간')
plt.ylabel('(명)')
plt.title("'각 학습에 소요된 평균 시간'과 '구독 연장'의 관계")
plt.xticks(np.arange(0, 501, 20))
plt.ylabel('(명)', rotation= 0)

plt.legend()
plt.show()

# %%
data_act = data[['monthly_active_learning_days', 'target']]
data_act
# Out:
#       monthly_active_learning_days  target
# 0                               18       0
# 1                               16       1
# 2                               13       1
# 3                               19       1
# 4                               19       1
# ...                            ...     ...
# 9995                            18       1
# 9996                             9       1
# 9997                            24       1
# 9998                            10       1
# 9999                             3       0
#
# [10000 rows x 2 columns]

# %%
colors = ['#a09cc9', '#6fb0d6']

x = data_act['monthly_active_learning_days']
y = data_act['target']

count_target_by_days = data_act.groupby('monthly_active_learning_days')['target'].value_counts().unstack().fillna(0)

plt.figure(figsize=(10, 6))
count_target_by_days.plot(kind='bar', rot=0, color=colors, width=0.6)
plt.xlabel('월간 활동적인 학습 일수')
plt.ylabel('(명)')
plt.ylabel('(명)', rotation= 0)
plt.title('월간 활동적인 학습 일수와 구독 연장의 관계')
plt.legend(title='Target', labels=['0', '1'], loc='upper right')
plt.show()

# %%
data_com = data[['community_engagement_level', 'target']]
data_com
# Out:
#       community_engagement_level  target
# 0                              4       0
# 1                              3       1
# 2                              4       1
# 3                              3       1
# 4                              4       1
# ...                          ...     ...
# 9995                           5       1
# 9996                           3       1
# 9997                           5       1
# 9998                           5       1
# 9999                           5       0
#
# [10000 rows x 2 columns]

# %%
com_counts = data_com.groupby('community_engagement_level')['target'].value_counts().unstack(fill_value=0)
com_counts
# Out:
# target                         0     1
# community_engagement_level
# 1                            211   348
# 2                            468   751
# 3                            620   968
# 4                            805  1265
# 5                           1697  2867

# %%
colors = ['#a09cc9', '#6fb0d6']

com_counts.plot(kind='bar', rot=0, color=colors, width=0.6)
plt.title('커뮤니티 참여도과 구독 연장의 관계')
plt.xlabel('커뮤티니 참여도')
plt.ylabel('구독 연장 고객수')

plt.show()

# %%
df_corr = data[['total_completed_courses', 'recent_learning_achievement', 'preferred_difficulty_level']]
df_corr
# Out:
#       total_completed_courses  recent_learning_achievement  \
# 0                          16                    68.360455
# 1                          13                    97.567322
# 2                          14                    94.358763
# 3                          18                    70.153228
# 4                          10                    81.917908
# ...                       ...                          ...
# 9995                       16                    64.966803
# 9996                        8                    82.750244
# 9997                       14                    81.567839
# 9998                       10                    89.885656
# 9999                       13                    64.811297
#
#      preferred_difficulty_level
# 0                           Low
# 1                        Medium
# 2                        Medium
# 3                           Low
# 4                        Medium
# ...                         ...
# 9995                        Low
# 9996                     Medium
# 9997                       High
# 9998                        Low
# 9999                        Low
#
# [10000 rows x 3 columns]

# %%
# 선호하는 레벨의 데이터를 숫자로 변경 (상관관계를 분석하기 위함)
df_corr.loc[:, 'preferred_difficulty_level'] = df_corr['preferred_difficulty_level'].replace({'Low': 3, 'Medium': 5, 'High': 10}).astype(int)

df_corr
# Out:
#       total_completed_courses  recent_learning_achievement  \
# 0                          16                    68.360455
# 1                          13                    97.567322
# 2                          14                    94.358763
# 3                          18                    70.153228
# 4                          10                    81.917908
# ...                       ...                          ...
# 9995                       16                    64.966803
# 9996                        8                    82.750244
# 9997                       14                    81.567839
# 9998                       10                    89.885656
# 9999                       13                    64.811297
#
#       preferred_difficulty_level
# 0                              3
# 1                              5
# 2                              5
# 3                              3
# 4                              5
# ...                          ...
# 9995                           3
# 9996                           5
# 9997                          10
# 9998                           3
# 9999                           3
#
# [10000 rows x 3 columns]

# %%
corr2 = df_corr.corr()
corr2
# Out:
#                              total_completed_courses  \
# total_completed_courses                     1.000000
# recent_learning_achievement                -0.002416
# preferred_difficulty_level                 -0.215116
#
#                              recent_learning_achievement  \
# total_completed_courses                        -0.002416
# recent_learning_achievement                     1.000000
# preferred_difficulty_level                     -0.001156
#
#                              preferred_difficulty_level
# total_completed_courses                       -0.215116
# recent_learning_achievement                   -0.001156
# preferred_difficulty_level                     1.000000

# %%
sns.heatmap(corr2, annot=True, fmt=".1%", cmap='PuBu')
plt.xticks(rotation= -10)
plt.yticks(rotation= 0)
plt.show()

# %%
data_ach = data[['total_completed_courses', 'target']]
data_ach
# Out:
#       total_completed_courses  target
# 0                          16       0
# 1                          13       1
# 2                          14       1
# 3                          18       1
# 4                          10       1
# ...                       ...     ...
# 9995                       16       1
# 9996                        8       1
# 9997                       14       1
# 9998                       10       1
# 9999                       13       0
#
# [10000 rows x 2 columns]

# %%
data_ach.describe()
# Out:
#        total_completed_courses        target
# count             10000.000000  10000.000000
# mean                 12.227500      0.619900
# std                   3.634125      0.485435
# min                   1.000000      0.000000
# 25%                  10.000000      0.000000
# 50%                  12.000000      1.000000
# 75%                  15.000000      1.000000
# max                  27.000000      1.000000

# %%
ach_count = data_ach.groupby('total_completed_courses')['target'].value_counts().unstack(fill_value=0)
ach_count
# Out:
# target                     0    1
# total_completed_courses
# 1                          1    0
# 2                          3    7
# 3                          8   15
# 4                         16   44
# 5                         49  106
# 6                         95  143
# 7                        183  259
# 8                        231  368
# 9                        304  502
# 10                       333  611
# 11                       419  645
# 12                       428  677
# 13                       395  628
# 14                       352  584
# 15                       306  477
# 16                       210  353
# 17                       173  298
# 18                       116  210
# 19                        70  120
# 20                        45   70
# 21                        27   35
# 22                        15   15
# 23                        11   16
# 24                         5    7
# 25                         2    5
# 26                         2    3
# 27                         2    1

# %%
colors = ['#a09cc9', '#6fb0d6']

ach_count.plot(kind='bar', rot=0, color=colors, width=0.8)
plt.title('완료한 총 코스 수와 구독 연장의 관계')
plt.xlabel('완료한 총 코스 수')
plt.ylabel('구독 연장 고객수')

plt.show()

# %%
data_pat = data[['payment_pattern', 'target']]
data_pat
# Out:
#       payment_pattern  target
# 0                   5       0
# 1                   6       1
# 2                   7       1
# 3                   0       1
# 4                   0       1
# ...               ...     ...
# 9995                1       1
# 9996                7       1
# 9997                6       1
# 9998                0       1
# 9999                3       0
#
# [10000 rows x 2 columns]

# %%
pat_count = data_pat.groupby('payment_pattern')['target'].value_counts().unstack(fill_value=0)
pat_count
# Out:
# target             0    1
# payment_pattern
# 0                468  807
# 1                502  783
# 2                459  747
# 3                467  763
# 4                461  753
# 5                488  750
# 6                467  801
# 7                489  795

# %%
pat_count.plot(kind='bar', rot=0, color=colors, width=0.6)
plt.title('결제 패턴과 구독 연장의 관계')
plt.xlabel('결제 패턴')
plt.ylabel('구독 연장 고객수')

plt.show()
